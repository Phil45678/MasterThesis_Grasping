# %% [markdown]
# # Training data from cluster YCB

# %%
# Importing packages 
from os import path

import pandas as pd

import numpy as np 

from openpyxl import load_workbook

import csv

# %%
# Plotting session 
plot_session = 6

# %%
import sys
sys.path.append("../..")

# %%
# All folders 
basepath = path.abspath('')

folder_10K_2 = path.abspath(path.join(basepath, "..", "Figures/Training/custom_YCB_Data_Set/10K/seq_len_2"))
folder_10K_5 = path.abspath(path.join(basepath, "..", "Figures/Training/custom_YCB_Data_Set/10K/seq_len_5"))
folder_10K_10 = path.abspath(path.join(basepath, "..", "Figures/Training/custom_YCB_Data_Set/10K/seq_len_10"))

folder_15K_2 = path.abspath(path.join(basepath, "..", "Figures/Training/custom_YCB_Data_Set/15K/seq_len_2"))
folder_15K_5 = path.abspath(path.join(basepath, "..", "Figures/Training/custom_YCB_Data_Set/15K/seq_len_5"))
folder_15K_10 = path.abspath(path.join(basepath, "..", "Figures/Training/custom_YCB_Data_Set/15K/seq_len_10"))

folder_20K_2 = path.abspath(path.join(basepath, "..", "Figures/Training/custom_YCB_Data_Set/20K/seq_len_2"))
folder_20K_5 = path.abspath(path.join(basepath, "..", "Figures/Training/custom_YCB_Data_Set/20K/seq_len_5"))
folder_20K_10 = path.abspath(path.join(basepath, "..", "Figures/Training/custom_YCB_Data_Set/20K/seq_len_10"))

folder_nzo_2 = path.abspath(path.join(basepath, "..", "Figures/Training/custom_YCB_Data_Set/non_zero_only/seq_len_2"))
folder_nzo_5 = path.abspath(path.join(basepath, "..", "Figures/Training/custom_YCB_Data_Set/non_zero_only/seq_len_5"))
folder_nzo_10 = path.abspath(path.join(basepath, "..", "Figures/Training/custom_YCB_Data_Set/non_zero_only/seq_len_10"))

# %%
data_10K_2 = load_workbook(folder_10K_2 + '/Log_loss_acc_training_50_nb_epochs_1000.xlsx')
data_10K_5 = load_workbook(folder_10K_5 + '/Log_loss_acc_training_50_nb_epochs_1000.xlsx')
data_10K_10 = load_workbook(folder_10K_10 + '/Log_loss_acc_training_50_nb_epochs_1000.xlsx')

data_15K_2 = load_workbook(folder_15K_2 + '/Log_loss_acc_training_50_nb_epochs_1000.xlsx')
data_15K_5 = load_workbook(folder_15K_5 + '/Log_loss_acc_training_50_nb_epochs_1000.xlsx')
data_15K_10 = load_workbook(folder_15K_10 + '/Log_loss_acc_training_50_nb_epochs_1000.xlsx')

data_20K_2 = load_workbook(folder_20K_2 + '/Log_loss_acc_training_50_nb_epochs_1000.xlsx')
data_20K_5 = load_workbook(folder_20K_5 + '/Log_loss_acc_training_50_nb_epochs_1000.xlsx')
data_20K_10 = load_workbook(folder_20K_10 + '/Log_loss_acc_training_50_nb_epochs_1000.xlsx')

data_nzo_2 = load_workbook(folder_nzo_2 + '/Log_loss_acc_training_50_nb_epochs_1000.xlsx')
data_nzo_5 = load_workbook(folder_nzo_5 + '/Log_loss_acc_training_50_nb_epochs_1000.xlsx')
data_nzo_10 = load_workbook(folder_nzo_10 + '/Log_loss_acc_training_50_nb_epochs_1000.xlsx')

# %%
data_sheet_10K_2 = data_10K_2.active
data_sheet_10K_5 = data_10K_5.active
data_sheet_10K_10 = data_10K_10.active

data_sheet_15K_2 = data_15K_2.active
data_sheet_15K_5 = data_15K_5.active
data_sheet_15K_10 = data_15K_10.active

data_sheet_20K_2 = data_20K_2.active
data_sheet_20K_5 = data_20K_5.active
data_sheet_20K_10 = data_20K_10.active

data_sheet_nzo_2 = data_nzo_2.active
data_sheet_nzo_5 = data_nzo_5.active
data_sheet_nzo_10 = data_nzo_10.active

# %%
# Declaring data 
epochs_10K_2 = [] 
training_losses_10K_2 = [] 
validation_losses_10K_2 = []
training_accs_10K_2 = [] 
validation_acc_10K_2 = [] 

epochs_10K_5 = [] 
training_losses_10K_5 = [] 
validation_losses_10K_5 = []
training_accs_10K_5 = [] 
validation_acc_10K_5 = [] 

epochs_10K_10 = [] 
training_losses_10K_10 = [] 
validation_losses_10K_10 = []
training_accs_10K_10 = [] 
validation_acc_10K_10 = [] 

epochs_15K_2 = [] 
training_losses_15K_2 = [] 
validation_losses_15K_2 = []
training_accs_15K_2 = [] 
validation_acc_15K_2 = [] 

epochs_15K_5 = [] 
training_losses_15K_5 = [] 
validation_losses_15K_5 = []
training_accs_15K_5 = [] 
validation_acc_15K_5 = [] 

epochs_15K_10 = [] 
training_losses_15K_10 = [] 
validation_losses_15K_10 = []
training_accs_15K_10 = [] 
validation_acc_15K_10 = [] 

epochs_20K_2 = [] 
training_losses_20K_2 = [] 
validation_losses_20K_2 = []
training_accs_20K_2 = [] 
validation_acc_20K_2 = [] 

epochs_20K_5 = [] 
training_losses_20K_5 = [] 
validation_losses_20K_5 = []
training_accs_20K_5 = [] 
validation_acc_20K_5 = [] 

epochs_20K_10 = [] 
training_losses_20K_10 = [] 
validation_losses_20K_10 = []
training_accs_20K_10 = [] 
validation_acc_20K_10 = [] 

epochs_nzo_2 = [] 
training_losses_nzo_2 = [] 
validation_losses_nzo_2 = []
training_accs_nzo_2 = [] 
validation_acc_nzo_2 = [] 

epochs_nzo_5 = [] 
training_losses_nzo_5 = [] 
validation_losses_nzo_5 = []
training_accs_nzo_5 = [] 
validation_acc_nzo_5 = [] 

epochs_nzo_10 = [] 
training_losses_nzo_10 = [] 
validation_losses_nzo_10 = []
training_accs_nzo_10 = [] 
validation_acc_nzo_10 = []

# %%
# Function for loading from a xlsx file 
def load_from_xlsx(data_sheet): 
    epochs = [] 
    training_losses = [] 
    validation_losses = [] 
    training_accs = [] 
    validation_accs = [] 
    line_counter = 2
    while data_sheet.cell(line_counter, 1).value !=  None: 
        epochs.append(int(data_sheet.cell(line_counter, 1).value))
        training_losses.append(float(data_sheet.cell(line_counter, 2).value))
        validation_losses.append(float(data_sheet.cell(line_counter, 3).value))
        training_accs.append(float(data_sheet.cell(line_counter, 4).value)*100)
        validation_accs.append(float(data_sheet.cell(line_counter, 5).value)*100)
        line_counter += 1 
    
    return epochs, training_losses, validation_losses, training_accs, validation_accs

# %%
epochs_10K_2, training_losses_10K_2, validation_losses_10K_2, training_accs_10K_2, validation_accs_10K_2 = load_from_xlsx(data_sheet_10K_2)
epochs_10K_5, training_losses_10K_5, validation_losses_10K_5, training_accs_10K_5, validation_accs_10K_5 = load_from_xlsx(data_sheet_10K_5)
epochs_10K_10, training_losses_10K_10, validation_losses_10K_10, training_accs_10K_10, validation_accs_10K_10 = load_from_xlsx(data_sheet_10K_10)

epochs_15K_2, training_losses_15K_2, validation_losses_15K_2, training_accs_15K_2, validation_accs_15K_2 = load_from_xlsx(data_sheet_15K_2)
epochs_15K_5, training_losses_15K_5, validation_losses_15K_5, training_accs_15K_5, validation_accs_15K_5 = load_from_xlsx(data_sheet_15K_5)
epochs_15K_10, training_losses_15K_10, validation_losses_15K_10, training_accs_15K_10, validation_accs_15K_10 = load_from_xlsx(data_sheet_15K_10)

epochs_20K_2, training_losses_20K_2, validation_losses_20K_2, training_accs_20K_2, validation_accs_20K_2 = load_from_xlsx(data_sheet_20K_2)
epochs_20K_5, training_losses_20K_5, validation_losses_20K_5, training_accs_20K_5, validation_accs_20K_5 = load_from_xlsx(data_sheet_20K_5)
epochs_20K_10, training_losses_20K_10, validation_losses_20K_10, training_accs_20K_10, validation_accs_20K_10 = load_from_xlsx(data_sheet_20K_10)

epochs_nzo_2, training_losses_nzo_2, validation_losses_nzo_2, training_accs_nzo_2, validation_accs_nzo_2 = load_from_xlsx(data_sheet_nzo_2)
epochs_nzo_5, training_losses_nzo_5, validation_losses_nzo_5, training_accs_nzo_5, validation_accs_nzo_5 = load_from_xlsx(data_sheet_nzo_5)
epochs_nzo_10, training_losses_nzo_10, validation_losses_nzo_10, training_accs_nzo_10, validation_accs_nzo_10 = load_from_xlsx(data_sheet_nzo_10)

# %% [markdown]
# ## Plotting

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
import seaborn as sns
sns.set()

# %%
def plot_losses(epochs, training_losses, validation_losses, folder_name, title): 
    # Plotting the losses 
    plt.figure(figsize=(12, 6), dpi=80)
    plt.plot(epochs, training_losses, label = "training loss")
    plt.plot(epochs, validation_losses, label = "validation loss")
    plt.xlabel("Epoch")
    plt.ylabel("Categorical Crossentropy")
    plt.title(title)
    plt.legend(loc='upper right')
    plt.savefig(folder_name + "/training_validation_losses_plot_" + str(len(epochs)) + "_epochs_V" + str(plot_session) +".png")
    plt.show()

# %%
def plot_accuracies(epochs, training_accs, validation_loss, folder_name, title):
    # Plotting the accuracies  
    plt.figure(figsize=(12, 6), dpi=80)
    plt.plot(epochs, training_accs, label = "training accuracy")
    plt.plot(epochs, validation_loss, label = "validation accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Categorical accuracy")
    plt.title(title)
    plt.legend(loc='lower right')
    plt.savefig(folder_name + "/training_validation_accuracies_plot_" + str(len(epochs)) + "_epochs_V" + str(plot_session) +".png")
    plt.show()

# %% [markdown]
# ## Sequence length 2:

# %% [markdown]
# 10K

# %%
print("Training and validation loss:")
plot_losses(epochs_10K_2, training_losses_10K_2, validation_losses_10K_2, folder_10K_2, "")
print("Training and validation accuracy:")
plot_accuracies(epochs_10K_2, training_accs_10K_2, validation_accs_10K_2, folder_10K_2, "")
print("Highest validation accuracy achieved: ", max(validation_accs_10K_2))
# Out:
# Training and validation loss:
# Training and validation accuracy:
# Highest validation accuracy achieved:  48.4

# %% [markdown]
# 15K

# %%
print("Training and validation loss:")
plot_losses(epochs_15K_2, training_losses_15K_2, validation_losses_15K_2, folder_15K_2, "")
print("Training and validation accuracy:")
plot_accuracies(epochs_15K_2, training_accs_15K_2, validation_accs_15K_2, folder_15K_2, "")
print("Highest validation accuracy achieved: ", max(validation_accs_15K_2))
# Out:
# Training and validation loss:
# Training and validation accuracy:
# Highest validation accuracy achieved:  37.3375

# %% [markdown]
# 20K

# %%
print("Training and validation loss:")
plot_losses(epochs_20K_2, training_losses_20K_2, validation_losses_20K_2, folder_20K_2, "")
print("Training and validation accuracy:")
plot_accuracies(epochs_20K_2, training_accs_20K_2, validation_accs_20K_2, folder_20K_2, "")
print("Highest validation accuracy achieved: ", max(validation_accs_20K_2))
# Out:
# Training and validation loss:
# Training and validation accuracy:
# Highest validation accuracy achieved:  30.884375

# %% [markdown]
# non-zero only

# %%
print("Training and validation loss:")
plot_losses(epochs_nzo_2, training_losses_nzo_2, validation_losses_nzo_2, folder_nzo_2, "")
print("Training and validation accuracy:")
plot_accuracies(epochs_nzo_2, training_accs_nzo_2, validation_accs_nzo_2, folder_nzo_2, "")
print("Highest validation accuracy achieved: ", max(validation_accs_nzo_2))
# Out:
# Training and validation loss:
# Training and validation accuracy:
# Highest validation accuracy achieved:  59.95921142080217

# %% [markdown]
# ## Sequence length 5:

# %% [markdown]
# 10K

# %%
print("Training and validation loss:")
plot_losses(epochs_10K_5, training_losses_10K_5, validation_losses_10K_5, folder_10K_5, "")
print("Training and validation accuracy:")
plot_accuracies(epochs_10K_5, training_accs_10K_5, validation_accs_10K_5, folder_10K_5, "")
print("Highest validation accuracy achieved: ", max(validation_accs_10K_5))
# Out:
# Training and validation loss:
# Training and validation accuracy:
# Highest validation accuracy achieved:  59.29687500000001

# %% [markdown]
# 15K

# %%
print("Training and validation loss:")
plot_losses(epochs_15K_5, training_losses_15K_5, validation_losses_15K_5, folder_15K_5, "")
print("Training and validation accuracy:")
plot_accuracies(epochs_15K_5, training_accs_15K_5, validation_accs_15K_5, folder_15K_5, "")
print("Highest validation accuracy achieved: ", max(validation_accs_15K_5))
# Out:
# Training and validation loss:
# Training and validation accuracy:
# Highest validation accuracy achieved:  54.37499999999999

# %% [markdown]
# 20K

# %%
print("Training and validation loss:")
plot_losses(epochs_20K_5, training_losses_20K_5, validation_losses_20K_5, folder_20K_5, "")
print("Training and validation accuracy:")
plot_accuracies(epochs_20K_5, training_accs_20K_5, validation_accs_20K_5, folder_20K_5, "")
print("Highest validation accuracy achieved: ", max(validation_accs_20K_5))
# Out:
# Training and validation loss:
# Training and validation accuracy:
# Highest validation accuracy achieved:  52.9296875

# %% [markdown]
# non-zero only

# %%
print("Training and validation loss:")
plot_losses(epochs_nzo_5, training_losses_nzo_5, validation_losses_nzo_5, folder_nzo_5, "")
print("Training and validation accuracy:")
plot_accuracies(epochs_nzo_5, training_accs_nzo_5, validation_accs_nzo_5, folder_nzo_5, "")
print("Highest validation accuracy achieved: ", max(validation_accs_nzo_5))
# Out:
# Training and validation loss:
# Training and validation accuracy:
# Highest validation accuracy achieved:  82.52889191026512

# %% [markdown]
# ## Sequence length 10:

# %% [markdown]
# 10K

# %%
print("Training and validation loss:")
plot_losses(epochs_10K_10, training_losses_10K_10, validation_losses_10K_10, folder_10K_10, "")
print("Training and validation accuracy:")
plot_accuracies(epochs_10K_10, training_accs_10K_10, validation_accs_10K_10, folder_10K_10, "")
print("Highest validation accuracy achieved: ", max(validation_accs_10K_10))
# Out:
# Training and validation loss:
# Training and validation accuracy:
# Highest validation accuracy achieved:  72.125

# %% [markdown]
# 15K

# %%
print("Training and validation loss:")
plot_losses(epochs_15K_10, training_losses_15K_10, validation_losses_15K_10, folder_15K_10, "")
print("Training and validation accuracy:")
plot_accuracies(epochs_15K_10, training_accs_15K_10, validation_accs_15K_10, folder_15K_10, "")
print("Highest validation accuracy achieved: ", max(validation_accs_15K_10))
# Out:
# Training and validation loss:
# Training and validation accuracy:
# Highest validation accuracy achieved:  63.645833333333336

# %% [markdown]
# 20K

# %%
print("Training and validation loss:")
plot_losses(epochs_20K_10, training_losses_20K_10, validation_losses_20K_10, folder_20K_10, "")
print("Training and validation accuracy:")
plot_accuracies(epochs_20K_10, training_accs_20K_10, validation_accs_20K_10, folder_20K_10, "")
print("Highest validation accuracy achieved: ", max(validation_accs_20K_10))
# Out:
# Training and validation loss:
# Training and validation accuracy:
# Highest validation accuracy achieved:  62.984375

# %% [markdown]
# non-zero only

# %%
print("Training and validation loss:")
plot_losses(epochs_nzo_10, training_losses_nzo_10, validation_losses_nzo_10, folder_nzo_10, "")
print("Training and validation accuracy:")
plot_accuracies(epochs_nzo_10, training_accs_nzo_10, validation_accs_nzo_10, folder_nzo_10, "")
print("Highest validation accuracy achieved: ", max(validation_accs_nzo_10))
# Out:
# Training and validation loss:
# Training and validation accuracy:
# Highest validation accuracy achieved:  64.30999320190347
